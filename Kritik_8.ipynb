# %%
#defining variables
x0 = 0.1
y0 = 0.1
alpha = 0.1
num_iterations = 10

# defining the function
def gradient (x0, yo, fun_1, grad_fun_1, alpha, num_iterations): #consider all variable inputs
    x = x0 # initialize
    y = y0 # initialize

#the for loop in given code
    for i in range(num_iterations):
        gradient_x, gradient_y = grad_fun_a (x, y)

        # step in the opposite direction of the gradient
        x = x - alpha * gradient_x
        y = y - alpha * gradient_y

    return x, y

#defining the function to take derivative
def fun_a(x, y) :
    return x**2 + y**2
    
#partial derivatives
def grad_fun_a(x, y) :
    grad_x = 2*x
    grad_y = 2*y
    
    return grad_x, grad_y
#output
result = gradient (x0, y0, fun_a, grad_fun_a, alpha, num_iterations) # calling the function
print ("Optimal values:", result)
# Out:
# Optimal values: (0.010737418240000003, 0.010737418240000003)

# %%
 import numpy as np 
import matplotlib. pyplot as plt

#defining variables
x0 = 0
y0 = 1 
alpha = 0.01 
num_iterations = 10000 
h = 0.01

#defining function
def gradient (x0, yo, fun_2, grad_fun_2, alpha, num_iterations): 
    x = x0 
    y = y0  

# given for loop again
    for i in range (num_iterations) :
        gradient_x, gradient_y = grad_fun_2(x, y)

        x = x - alpha * gradient_x
        y = y - alpha * gradient_y        
    return x, y 

#the function as given in part b
def fun_b(x, y) :
    return 1-np.exp(-x**2-(y-2)**2)-2*np.exp(-x**2-(y+2)**2)


 # the gradeint (using the partial derivatives)
def grad_fun_b(x,y):
    grad_x2 = fun_b(x+h,y)- (fun_b(x,y))/h 
    grad_y2 = fun_b(x,y+h)- (fun_b(x,y))/h 
    return grad_x2, grad_y2 

#output
result = gradient(x0, y0, fun_b, grad_fun_b, alpha, num_iterations)
print ("Optimal values:", result)

#Plotting the function
import numpy as np
from mpl_toolkits import mplot3d #for 3D plots import matplotlib.pyplot as plt #usual matplotlib matplotlib widget

X=np.linspace(-5, 5,100)
Y=np.linspace(-5, 5, 100)
x,y=np.meshgrid(X,Y)
z=fun_b(x, y)
    
fig = plt.figure()
ax = plt.axes (projection='3d')
plt.title("Question 4B Kritik 8 Graph" )
ax.plot_surface(x, y, z, cmap='viridis', edgecolor='none')
# Out:
# Optimal values: (9898.677322814636, 9899.677589292705)

# %%
#defining variables 
x0 = -1
y0 = 1
alpha = 0.01
num_iterations = 100

#redefining function
def gradient (x0, yo, fun_a, grad_fun_a, alpha, num_iterations):
    x = x0
    y = y0

    for i in range (num_iterations):
        gradient_x, gradient_y = grad_fun_a(x, y)
        
        x = x - alpha * gradient_x
        y = y - alpha * gradient_y
        
    return x, y

#setting up partial derivatives 
def fun_a(x, y) :
    return x**2 + y**2
    
def grad_fun_a(x, y) :
    grad_x = 2*x
    grad_y = 2*y
    
    return grad_x, grad_y
    
result = gradient(x0, y0, fun_a, grad_fun_a, alpha, num_iterations)
print ("Optimal values:", result)
# Out:
# Optimal values: (-0.13261955589475316, 0.13261955589475316)
